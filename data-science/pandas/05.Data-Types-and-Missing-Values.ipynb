# %% [markdown]
# ## Data Types and Missing Values

# %% [markdown]
# ### DType

# %%
import pandas as pd
reviews = pd.read_csv("./hotel_bookings.csv")
reviews
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# ...

# %%
reviews.lead_time.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Missing data

# %%
reviews[pd.isnull(reviews.hotel)]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []
#
# [0 rows x 32 columns]

# %%
reviews.lead_time.fillna("Unknow")
# Out:
# 0     342
# 1     737
# 2       7
# 3      13
# 4      14
# 5      14
# 6       0
# 7       9
# 8      85
# 9      75
# 10     23
# 11     35
# 12     68
# 13     18
# 14     37
# 15     68
# 16     37
# 17     12
# 18      0
# 19      7
# 20     37
# 21     72
# 22     72
# 23     72
# 24    127
# 25     78
# 26     48
# 27     60
# 28     77
# 29     99
#      ...
# 69     63
# 70     62
# 71    101
# 72      2
# 73     15
# 74     51
# 75      3
# 76     48
# 77      2
# 78     72
# 79     81
# 80     99
# 81    368
# 82    364
# 83     81
# 84     99
# 85    324
# 86     69
# 87     79
# 88     12
# 89      9
# 90      1
# 91     21
# 92      9
# 93    109
# 94    109
# 95     72
# 96     63
# 97     63
# 98    101
# Name: lead_time, Length: 99, dtype: int64

# %%
## 只能全值匹配
reviews.hotel.replace("Resort Hotel", "QuanJi")
# Out:
# 0     QuanJi
# 1     QuanJi
# 2     QuanJi
# 3     QuanJi
# 4     QuanJi
# 5     QuanJi
# 6     QuanJi
# 7     QuanJi
# 8     QuanJi
# 9     QuanJi
# 10    QuanJi
# 11    QuanJi
# 12    QuanJi
# 13    QuanJi
# 14    QuanJi
# 15    QuanJi
# 16    QuanJi
# 17    QuanJi
# 18    QuanJi
# 19    QuanJi
# 20    QuanJi
# 21    QuanJi
# 22    QuanJi
# 23    QuanJi
# 24    QuanJi
# 25    QuanJi
# 26    QuanJi
# 27    QuanJi
# 28    QuanJi
# 29    QuanJi
#        ...
# 69    QuanJi
# 70    QuanJi
# 71    QuanJi
# 72    QuanJi
# 73    QuanJi
# 74    QuanJi
# 75    QuanJi
# 76    QuanJi
# 77    QuanJi
# 78    QuanJi
# 79    QuanJi
# 80    QuanJi
# 81    QuanJi
# 82    QuanJi
# 83    QuanJi
# 84    QuanJi
# 85    QuanJi
# 86    QuanJi
# 87    QuanJi
# 88    QuanJi
# 89    QuanJi
# 90    QuanJi
# 91    QuanJi
# 92    QuanJi
# 93    QuanJi
# 94    QuanJi
# 95    QuanJi
# 96    QuanJi
# 97    QuanJi
# 98    QuanJi
# Name: hotel, Length: 99, dtype: object
