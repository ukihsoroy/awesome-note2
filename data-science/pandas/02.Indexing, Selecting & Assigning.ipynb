# %%
# Native accessors

# %%
import pandas as pd

# %%
reviews = pd.read_csv("./hotel_bookings.csv")

# %%
reviews
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# ...

# %%
reviews.hotel
# Out:
# 0     Resort Hotel
# 1     Resort Hotel
# 2     Resort Hotel
# 3     Resort Hotel
# 4     Resort Hotel
# 5     Resort Hotel
# 6     Resort Hotel
# 7     Resort Hotel
# 8     Resort Hotel
# 9     Resort Hotel
# 10    Resort Hotel
# 11    Resort Hotel
# 12    Resort Hotel
# 13    Resort Hotel
# 14    Resort Hotel
# 15    Resort Hotel
# 16    Resort Hotel
# 17    Resort Hotel
# 18    Resort Hotel
# 19    Resort Hotel
# 20    Resort Hotel
# 21    Resort Hotel
# 22    Resort Hotel
# 23    Resort Hotel
# 24    Resort Hotel
# 25    Resort Hotel
# 26    Resort Hotel
# 27    Resort Hotel
# 28    Resort Hotel
# 29    Resort Hotel
#           ...
# 69    Resort Hotel
# 70    Resort Hotel
# 71    Resort Hotel
# 72    Resort Hotel
# 73    Resort Hotel
# 74    Resort Hotel
# 75    Resort Hotel
# 76    Resort Hotel
# 77    Resort Hotel
# 78    Resort Hotel
# 79    Resort Hotel
# 80    Resort Hotel
# 81    Resort Hotel
# 82    Resort Hotel
# 83    Resort Hotel
# 84    Resort Hotel
# ...

# %%
reviews['hotel']
# Out:
# 0     Resort Hotel
# 1     Resort Hotel
# 2     Resort Hotel
# 3     Resort Hotel
# 4     Resort Hotel
# 5     Resort Hotel
# 6     Resort Hotel
# 7     Resort Hotel
# 8     Resort Hotel
# 9     Resort Hotel
# 10    Resort Hotel
# 11    Resort Hotel
# 12    Resort Hotel
# 13    Resort Hotel
# 14    Resort Hotel
# 15    Resort Hotel
# 16    Resort Hotel
# 17    Resort Hotel
# 18    Resort Hotel
# 19    Resort Hotel
# 20    Resort Hotel
# 21    Resort Hotel
# 22    Resort Hotel
# 23    Resort Hotel
# 24    Resort Hotel
# 25    Resort Hotel
# 26    Resort Hotel
# 27    Resort Hotel
# 28    Resort Hotel
# 29    Resort Hotel
#           ...
# 69    Resort Hotel
# 70    Resort Hotel
# 71    Resort Hotel
# 72    Resort Hotel
# 73    Resort Hotel
# 74    Resort Hotel
# 75    Resort Hotel
# 76    Resort Hotel
# 77    Resort Hotel
# 78    Resort Hotel
# 79    Resort Hotel
# 80    Resort Hotel
# 81    Resort Hotel
# 82    Resort Hotel
# 83    Resort Hotel
# 84    Resort Hotel
# ...

# %%
reviews['hotel'][0]
# Out:
# 'Resort Hotel'

# %%
reviews.iloc[0]
# Out:
# hotel                             Resort Hotel
# is_canceled                                  0
# lead_time                                  342
# arrival_date_year                         2015
# arrival_date_month                        July
# arrival_date_week_number                    27
# arrival_date_day_of_month                    1
# stays_in_weekend_nights                      0
# stays_in_week_nights                         0
# adults                                       2
# children                                     0
# babies                                       0
# meal                                        BB
# country                                    PRT
# market_segment                          Direct
# distribution_channel                    Direct
# is_repeated_guest                            0
# previous_cancellations                       0
# previous_bookings_not_canceled               0
# reserved_room_type                           C
# ...

# %%
reviews.iloc[:, 0]
# Out:
# 0     Resort Hotel
# 1     Resort Hotel
# 2     Resort Hotel
# 3     Resort Hotel
# 4     Resort Hotel
# 5     Resort Hotel
# 6     Resort Hotel
# 7     Resort Hotel
# 8     Resort Hotel
# 9     Resort Hotel
# 10    Resort Hotel
# 11    Resort Hotel
# 12    Resort Hotel
# 13    Resort Hotel
# 14    Resort Hotel
# 15    Resort Hotel
# 16    Resort Hotel
# 17    Resort Hotel
# 18    Resort Hotel
# 19    Resort Hotel
# 20    Resort Hotel
# 21    Resort Hotel
# 22    Resort Hotel
# 23    Resort Hotel
# 24    Resort Hotel
# 25    Resort Hotel
# 26    Resort Hotel
# 27    Resort Hotel
# 28    Resort Hotel
# 29    Resort Hotel
#           ...
# 69    Resort Hotel
# 70    Resort Hotel
# 71    Resort Hotel
# 72    Resort Hotel
# 73    Resort Hotel
# 74    Resort Hotel
# 75    Resort Hotel
# 76    Resort Hotel
# 77    Resort Hotel
# 78    Resort Hotel
# 79    Resort Hotel
# 80    Resort Hotel
# 81    Resort Hotel
# 82    Resort Hotel
# 83    Resort Hotel
# 84    Resort Hotel
# ...

# %%
reviews.iloc[:3, 0]
# Out:
# 0    Resort Hotel
# 1    Resort Hotel
# 2    Resort Hotel
# Name: hotel, dtype: object

# %%
reviews.iloc[1:3, 0]
# Out:
# 1    Resort Hotel
# 2    Resort Hotel
# Name: hotel, dtype: object

# %%
reviews.iloc[[0, 1, 2], 0]
# Out:
# 0    Resort Hotel
# 1    Resort Hotel
# 2    Resort Hotel
# Name: hotel, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 94  Resort Hotel            1        109               2015
# 95  Resort Hotel            1         72               2015
# 96  Resort Hotel            1         63               2015
# 97  Resort Hotel            0         63               2015
# 98  Resort Hotel            0        101               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 94               July                        27                          3
# 95               July                        27                          3
# 96               July                        27                          3
# 97               July                        27                          3
# 98               July                        27                          3
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  \
# 94                        0                     2       2
# ...

# %%
reviews.loc[0, 'hotel']
# Out:
# 'Resort Hotel'

# %%
reviews.loc[:, ['hotel', 'is_canceled', 'lead_time']]
# Out:
#            hotel  is_canceled  lead_time
# 0   Resort Hotel            0        342
# 1   Resort Hotel            0        737
# 2   Resort Hotel            0          7
# 3   Resort Hotel            0         13
# 4   Resort Hotel            0         14
# 5   Resort Hotel            0         14
# 6   Resort Hotel            0          0
# 7   Resort Hotel            0          9
# 8   Resort Hotel            1         85
# 9   Resort Hotel            1         75
# 10  Resort Hotel            1         23
# 11  Resort Hotel            0         35
# 12  Resort Hotel            0         68
# 13  Resort Hotel            0         18
# 14  Resort Hotel            0         37
# 15  Resort Hotel            0         68
# 16  Resort Hotel            0         37
# 17  Resort Hotel            0         12
# 18  Resort Hotel            0          0
# 19  Resort Hotel            0          7
# 20  Resort Hotel            0         37
# 21  Resort Hotel            0         72
# ...

# %% [markdown]
# # Manipulating the index

# %%
reviews.set_index("hotel")
# Out:
#               is_canceled  lead_time  arrival_date_year arrival_date_month  \
# hotel
# Resort Hotel            0        342               2015               July
# Resort Hotel            0        737               2015               July
# Resort Hotel            0          7               2015               July
# Resort Hotel            0         13               2015               July
# Resort Hotel            0         14               2015               July
# Resort Hotel            0         14               2015               July
# Resort Hotel            0          0               2015               July
# Resort Hotel            0          9               2015               July
# Resort Hotel            1         85               2015               July
# Resort Hotel            1         75               2015               July
# Resort Hotel            1         23               2015               July
# ...

# %%
reviews.hotel == 'Resort Hotel'
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
#       ...
# 69    True
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True
# 81    True
# 82    True
# 83    True
# 84    True
# 85    True
# 86    True
# 87    True
# 88    True
# 89    True
# 90    True
# 91    True
# 92    True
# 93    True
# 94    True
# 95    True
# 96    True
# 97    True
# 98    True
# Name: hotel, Length: 99, dtype: bool

# %%
reviews.loc[reviews.hotel == 'Resort Hotel']
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# ...

# %%
reviews.loc[(reviews.hotel == 'Resort Hotel') & (reviews.lead_time >= 90)]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 24  Resort Hotel            0        127               2015
# 29  Resort Hotel            0         99               2015
# 30  Resort Hotel            0        118               2015
# 31  Resort Hotel            0         95               2015
# 32  Resort Hotel            1         96               2015
# 44  Resort Hotel            0        107               2015
# 46  Resort Hotel            0         96               2015
# 47  Resort Hotel            0        113               2015
# 48  Resort Hotel            0         90               2015
# 50  Resort Hotel            0        113               2015
# 51  Resort Hotel            0         93               2015
# 63  Resort Hotel            0         93               2015
# 71  Resort Hotel            1        101               2015
# ...

# %%
reviews.loc[reviews.hotel.isin(['Resort Hotel'])]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# ...

# %%
reviews.loc[reviews.hotel.notnull()]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# ...

# %% [markdown]
# ## Assigning data

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0     everyone
# 1     everyone
# 2     everyone
# 3     everyone
# 4     everyone
# 5     everyone
# 6     everyone
# 7     everyone
# 8     everyone
# 9     everyone
# 10    everyone
# 11    everyone
# 12    everyone
# 13    everyone
# 14    everyone
# 15    everyone
# 16    everyone
# 17    everyone
# 18    everyone
# 19    everyone
# 20    everyone
# 21    everyone
# 22    everyone
# 23    everyone
# 24    everyone
# 25    everyone
# 26    everyone
# 27    everyone
# 28    everyone
# 29    everyone
#         ...
# 69    everyone
# 70    everyone
# 71    everyone
# 72    everyone
# 73    everyone
# 74    everyone
# 75    everyone
# 76    everyone
# 77    everyone
# 78    everyone
# 79    everyone
# 80    everyone
# 81    everyone
# 82    everyone
# 83    everyone
# 84    everyone
# 85    everyone
# 86    everyone
# 87    everyone
# 88    everyone
# 89    everyone
# 90    everyone
# 91    everyone
# 92    everyone
# 93    everyone
# 94    everyone
# 95    everyone
# 96    everyone
# ...

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0     99
# 1     98
# 2     97
# 3     96
# 4     95
# 5     94
# 6     93
# 7     92
# 8     91
# 9     90
# 10    89
# 11    88
# 12    87
# 13    86
# 14    85
# 15    84
# 16    83
# 17    82
# 18    81
# 19    80
# 20    79
# 21    78
# 22    77
# 23    76
# 24    75
# 25    74
# 26    73
# 27    72
# 28    71
# 29    70
#       ..
# 69    30
# 70    29
# 71    28
# 72    27
# 73    26
# 74    25
# 75    24
# 76    23
# 77    22
# 78    21
# 79    20
# 80    19
# 81    18
# 82    17
# 83    16
# 84    15
# 85    14
# 86    13
# 87    12
# 88    11
# 89    10
# 90     9
# 91     8
# 92     7
# 93     6
# 94     5
# 95     4
# 96     3
# 97     2
# 98     1
# Name: index_backwards, Length: 99, dtype: int32
